# %%
import pandas as pd
import numpy as np

# %%
# Basic plotting
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))

df.plot()

# %%
# Bar plot
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()

# %%
# Produce a stacked bar plot
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)

# %%
# Produce a horizontal bar plot
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

df.plot.barh(stacked=True)

# %%
# Histograms
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.plot.hist(bins=20)

# %%
# Plot different histograms for each column
df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCABFDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDB83B688>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCB19E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCB4E088>]],
#       dtype=object)

# %%
# Box plots
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()

# %%
# Area plots
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()

# %%
# Scatter plot
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')

# %%
# Pie chart
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCE61A08>],
#       dtype=object)
