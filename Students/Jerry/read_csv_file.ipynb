# %%
# Step 1: Import the pandas library
import pandas as pd

# Step 2: Load the CSV file
df = pd.read_csv('Habitable Planets - 2nd - 工作表1.csv')

# Step 3: Display the first 5 rows
df.head()
# Out:
#        pl_name  pl_orbsmax  pl_dens  st_met   st_lum  st_age
# 0   Wolf 327 b     0.01000     7.24  -0.170 -1.62986     4.1
# 1    TOI-561 b     0.01060     4.80  -0.410 -0.28233    10.0
# 2  TOI-1798.02     0.01070    11.17   0.073 -0.41567     2.6
# 3   TOI-1444 b     0.01160     6.84   0.146 -0.17587     3.8
# 4   LTT 3780 b     0.01195     5.80   0.060 -1.78252     3.1
