# %%
import os
import pandas as pd
from skimage import io

# %%
# Get the current path
current_path = os.getcwd()
current_path
# Out:
# 'E:\\MyProject\\SourceCode\\Python-DataScience\\ImageProcessing\\PracticalMachineLearning'

# %%
# Read image file and display 
img = io.imread(current_path +'\\puppy.jpg')
io.imshow(img)

# %%
# Get image resolution
img.shape
# Out:
# (486, 729, 3)

# %%
# Get Pixel Values
df = pd.DataFrame(img.flatten())

# %%
# Write into a file
filepath = 'pixel_values1.xlsx'
df.to_excel(filepath, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c1474a447052> in <module>
#       1 # Write into a file
#       2 filepath = 'pixel_values1.xlsx'
# ----> 3 df.to_excel(filepath, index=False)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\envs\JetsonNano\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2254             startcol=startcol,
#    2255             freeze_panes=freeze_panes,
# -> 2256             engine=engine,
#    2257         )
#    2258
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\envs\JetsonNano\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     722                 "This sheet is too large! Your sheet size is: "
#     723                 + "{}, {} ".format(num_rows, num_cols)
# --> 724                 + "Max sheet size is: {}, {}".format(self.max_rows, self.max_cols)
#     725             )
#     726
#
# ValueError: This sheet is too large! Your sheet size is: 1062882, 1 Max sheet size is: 1048576, 16384
